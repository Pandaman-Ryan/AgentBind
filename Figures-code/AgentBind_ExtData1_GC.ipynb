# %%
# %pylab inline

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
import os
import pandas as pd
import scipy.stats

data = pd.read_csv("AgentBindGCPerformance.txt", sep="\t")
factors = list(data["TF"].values)
x = list((data["GC.pos"]-data["GC.neg"]).apply(abs))
y1 = list(data["AUC.blocked"])
y2 = list(data["AUC.notblocked"])

fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(x, y1, color="darkblue");
ax.set_xlabel("|GCpos-GCneg|")
ax.set_ylabel("AUC.blocked")
ax.set_ylim(bottom=0.75, top=1.01)
for i, txt in enumerate(factors):
    ax.annotate(txt, (x[i], y1[i]), fontsize="small")
fig.savefig("/storage/mgymrek/agent-bind/figures/AgentBind_SuppFig_GC_Blocked.pdf")
print(scipy.stats.pearsonr(x, y1))

fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(x, y2, color="darkblue");
ax.set_xlabel("|GCpos-GCneg|")
ax.set_ylabel("AUC.notblocked")
for i, txt in enumerate(factors):
    ax.annotate(txt, (x[i], y2[i]), fontsize="small")
ax.set_ylim(bottom=0.75, top=1.01)
fig.savefig("/storage/mgymrek/agent-bind/figures/AgentBind_SuppFig_GC_NotBlocked.pdf")
print(scipy.stats.pearsonr(x, y2))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (0.6557380635828084, 7.867330293495277e-06)
# (0.5840560002503505, 0.00011828257805705082)

# %%
data
# Out:
#          TF    GC.pos    GC.neg  AUC.blocked  AUC.notblocked
# 0      CTCF  0.493997  0.493884     0.798141        0.944757
# 1      EBF1  0.501926  0.468860     0.882005        0.892479
# 2       SP1  0.605997  0.491642     0.954729        0.962353
# 3       PU1  0.441472  0.401384     0.823172        0.944836
# 4     RUNX3  0.449481  0.406993     0.899736        0.897765
# 5      NFYB  0.509410  0.443526     0.915190        0.920042
# 6      Nrf1  0.644897  0.561266     0.951713        0.956224
# 7      ELF1  0.574496  0.433046     0.971415        0.972581
# 8      NFKB  0.475533  0.440387     0.892354        0.918770
# 9      TCF3  0.536410  0.459562     0.935515        0.947136
# 10     Mxi1  0.598961  0.481204     0.956363        0.958797
# 11     USF1  0.536959  0.443112     0.934576        0.943205
# 12      YY1  0.521457  0.427404     0.930794        0.921934
# 13     USF2  0.524007  0.441320     0.937584        0.941287
# 14     ZEB1  0.579759  0.470058     0.954963        0.955143
# 15     PAX5  0.548820  0.474596     0.890385        0.914504
# 16   POU2F2  0.444717  0.376973     0.947515        0.949367
# 17     NRSF  0.532281  0.481316     0.813471        0.880422
# 18     PBX3  0.528227  0.450572     0.956157        0.944927
# 19    MEF2A  0.416247  0.384506     0.951894        0.948206
# 20     E2F4  0.626929  0.544565     0.955261        0.970034
# 21  BHLHE40  0.552221  0.456758     0.930933        0.944054
# 22     ELK1  0.593690  0.462890     0.963304        0.968037
# 23     NFIC  0.476019  0.447292     0.916696        0.918750
# 24    MEF2C  0.422570  0.385903     0.964726        0.971329
# 25      Max  0.548673  0.420946     0.968971        0.968081
# 26      SRF  0.468543  0.404276     0.838833        0.846671
# 27   Znf143  0.543576  0.431966     0.975424        0.992562
# 28     IRF4  0.439586  0.388005     0.896869        0.936422
# 29   ZBTB33  0.594458  0.524799     0.937021        0.947815
# 30     NFYA  0.591522  0.436913     0.990042        0.993330
# 31     ETS1  0.592550  0.455811     0.954144        0.963426
# 32     RFX5  0.546223  0.464027     0.954256        0.969089
# 33    STAT3  0.450885  0.415535     0.863537        0.898423
# 34     JunD  0.406518  0.409332     0.928897        0.906524
# 35    CEBPB  0.441661  0.401409     0.935268        0.945971
# 36    STAT1  0.527726  0.405790     0.977273        0.982143
# 37      FOS  0.498218  0.406297     0.937500        0.919643
